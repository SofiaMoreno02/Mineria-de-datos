# %% [markdown]
# ## Tarea 1 Minería de datos

# %% [markdown]
# ### Julieth Sofia Moreno Ahumada

# %% [markdown]
# #### Texto Normal

# %%
print("Para crear cualquier texto una alternativa es usar la función print")
# Out:
# Para crear cualquier texto una alternativa es usar la función print

# %% [markdown]
# #### Contenido Latex en Markdown

# %% [markdown]
# Para crear contenido latex usamos los símbolos pesos, y todo lo que quede entre estos símbolos será en formato latex, por ejemplo $\sin(y)$, o usamos signos dobles para que quede centrado como por ejemplo $$ \sin(y)$$

# %% [markdown]
# #### HTML

# %%
import webbrowser
f = open('ejemplo.html','w')

mensaje = """<html>
<head></head>
<body><p>Ejemplo de un mensaje HTML</p></body>
</html>"""

f.write(mensaje)
f.close()
webbrowser.open_new_tab('ejemplo.html')
# Out:
# True

# %% [markdown]
# #### Enlaces

# %% [markdown]
# ##### Enlace imagen

# %% [markdown]
# [Ejemplo de imagen 1](https://www.dataquest.io/wp-content/uploads/2019/01/1-LPnY8nOLg4S6_TG0DEXwsg-1.png)

# %% [markdown]
# [Ejemplo de imagen 2](https://upload.wikimedia.org/wikipedia/commons/thumb/c/c3/Python-logo-notext.svg/800px-Python-logo-notext.svg.png)

# %% [markdown]
# Estos enlaces a imagenes fueron creados usando markdown

# %% [markdown]
# ##### Enlace video

# %%
from IPython.display import YouTubeVideo
video = YouTubeVideo('AUQT0MKpf6Y')
display(video)
